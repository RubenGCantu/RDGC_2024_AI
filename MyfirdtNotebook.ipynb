# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # Introduction
#
# This is my first notebook in colab

# %% [markdown]
# # Nueva sección

# %%
print("Hello world")
# Out:
# Hello world
